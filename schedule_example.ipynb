# %%
from time import time
from collector import * 
from selector import *
from resource_mock import Resource

# %%
time_range = Time(["2019-02-02 08:00:00", "2019-05-01 08:00:00"], format='iso', scale='utc')
night_date = '2019-01-03'

# The semesters to consider for the plan
obs_classes = ['SCIENCE', 'PROG_CAL', 'PARTNER_CAL']
prog_types = ['Q', 'LP', 'FT', 'DD']
sites = [Site('gs')]
semesters = ['2018B','2019A']

# %%
path = './collector/data'
collector = Collector(sites, semesters, prog_types, obs_classes, time_range=time_range)
collector.load(path)
print(f'Observations collected: {collector.nobs}')
# Out:
# ./collector/data/20190201-0830.zip
# ./collector/data/nightplans/20190202/
# GS-2018B-Q-205-21 is missing target component [READY]
# GS-2018B-Q-225-64 is missing target component [READY]
# GS-2018B-Q-225-133 is missing target component [READY]
# GS-2019A-FT-201-7 is missing target component [READY]
# GS-2019A-LP-1-31 is missing target component [READY]
# GS-2019A-Q-101-15 is missing target component [READY]
# GS-2019A-Q-101-18 is missing target component [READY]
# GS-2019A-Q-103-5 is missing target component [READY]
# GS-2019A-Q-104-7 is missing target component [READY]
# GS-2019A-Q-127-16 is missing target component [READY]
# GS-2019A-Q-133-7 is missing target component [READY]
# GS-2019A-Q-133-12 is missing target component [READY]
# GS-2019A-Q-206-7 is missing target component [READY]
# GS-2019A-Q-209-5 is missing target component [READY]
# GS-2019A-Q-213-5 is missing target component [READY]
# GS-2019A-Q-220-5 is missing target component [READY]
# GS-2019A-Q-221-7 is missing target component [READY]
# GS-2019A-Q-225-5 is missing target component [READY]
# GS-2019A-Q-227-5 is missing target component [READY]
# GS-2019A-Q-228-43 is missing target component [READY]
# GS-2019A-Q-229-7 is missing target component [READY]
# GS-2019A-Q-231-5 is missing target component [READY]
# GS-2019A-Q-232-7 is missing target component [READY]
# GS-2019A-Q-232-12 is missing target component [READY]
# GS-2019A-Q-237-7 is missing target component [READY]
# GS-2019A-Q-237-12 is missing target component [READY]
# GS-2019A-Q-303-27 Day Cal has no HORIZONS ID [READY]
# GS-2019A-Q-303-28 Day Cal has no HORIZONS ID [READY]
# GS-2019A-Q-303-29 Day Cal has no HORIZONS ID [READY]
# GS-2019A-Q-303-30 Day Cal has no HORIZONS ID [READY]
# GS-2019A-Q-303-31 Day Cal has no HORIZONS ID [READY]
# GS-2019A-Q-303-32 Day Cal has no HORIZONS ID [READY]
# GS-2019A-Q-310-17 is missing target component [READY]
# GS-2019A-Q-313-5 is missing target component [READY]
# GS-2019A-Q-314-5 is missing target component [READY]
# GS-2019A-Q-317-5 is missing target component [READY]
# GS-2019A-Q-402-5 is missing target component [READY]
# GS-2019A-Q-403-5 is missing target component [READY]
# Observations collected: 1222

# %%
# Resource API mock 
resource = Resource('/resource_mock/data')
resource.connect()
resources = resource.get_night_resources(sites,night_date)
resources.instruments[Site.GS]
# Out:
# Get Resource data...
# ['GPI', 'GCAL', 'GMOS-S', 'Canopus', 'F2']

# %%
# ephemid directory; should be file?

ephem_dir = path + '/ephem'
if not os.path.exists(ephem_dir):
    os.makedirs(ephem_dir)

selector = Selector(collector, sites, time_range=time_range)

actual_conditions = collector.get_actual_conditions()
# Out:
# WARNING: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)" [astropy._erfa.core]

# %%
visits = selector.create_pool()

for site in sites:
    selector.visibility(site, ephem_dir=ephem_dir)
# Out:
# 100%|██████████| 1222/1222 [00:06<00:00, 178.29it/s]
# Done

# %%
night_period = 0 
selection = { site: selector.select(visits[site], 
                                    night_period, 
                                    site, 
                                    actual_conditions, 
                                    resources, 
                                    ephem_dir) for site in sites}
selector.selection_summary()
# Out:
# Site GS
# Visit 2
#  -- observations:
#  ['3-GS-2018B-FT-111-5', '4-GS-2018B-FT-111-6']
# -- calibrations: []
#
# Visit 3
#  -- observations:
#  ['5-GS-2018B-FT-111-7', '6-GS-2018B-FT-111-8']
# -- calibrations: []
#
# Visit 41
#  -- observations:
#  ['69-GS-2018B-Q-225-24', '70-GS-2018B-Q-225-25', '71-GS-2018B-Q-225-123', '72-GS-2018B-Q-225-124']
# -- calibrations: []
#
# Visit 42
#  -- observations:
#  ['73-GS-2018B-Q-225-66', '74-GS-2018B-Q-225-67', '75-GS-2018B-Q-225-141', '76-GS-2018B-Q-225-142']
# -- calibrations: []
#
# Visit 43
#  -- observations:
#  ['77-GS-2018B-Q-225-18', '78-GS-2018B-Q-225-19', '79-GS-2018B-Q-225-117', '80-GS-2018B-Q-225-118']
# -- calibrations: []
#
# Visit 44
#  -- observations:
#  ['81-GS-2018B-Q-225-159', '82-GS-2018B-Q-225-160', '83-GS-2018B-Q-225-162', '84-GS-2018B-Q-225-163']
# -- calibrations: []
#
# Visit 45
#  -- observations:
#  ['85-GS-2018B-Q-225-93', '86-GS-2018B-Q-225-94', '87-GS-2018B-Q-225-150', '88-GS-2018B-Q-225-151']
# -- calibrations: []
#
# Visit 596
#  -- observations:
#  ['670-GS-2019A-LP-12-14']
# -- calibrations: []
#
# Visit 597
#  -- observations:
#  ['671-GS-2019A-LP-12-22']
# -- calibrations: []
#
# Visit 598
#  -- observations:
#  ['672-GS-2019A-LP-12-24']
# -- calibrations: []
#
# Visit 599
#  -- observations:
#  ['673-GS-2019A-LP-12-26']
# -- calibrations: []
#
# Visit 600
#  -- observations:
#  ['674-GS-2019A-LP-12-28']
# -- calibrations: []
#
# Visit 601
#  -- observations:
#  ['675-GS-2019A-LP-12-30']
# -- calibrations: []
#
# Visit 602
#  -- observations:
#  ['676-GS-2019A-LP-12-50']
# -- calibrations: []
#
# Visit 603
#  -- observations:
#  ['677-GS-2019A-LP-12-18']
# -- calibrations: []
#
# Visit 604
#  -- observations:
#  ['678-GS-2019A-LP-12-16']
# -- calibrations: []
#
# Visit 605
#  -- observations:
#  ['679-GS-2019A-LP-12-20']
# -- calibrations: []
#
# Visit 606
#  -- observations:
#  ['680-GS-2019A-LP-12-32']
# -- calibrations: []
#
# Visit 607
#  -- observations:
#  ['681-GS-2019A-LP-12-36']
# -- calibrations: []
#
# Visit 608
#  -- observations:
#  ['682-GS-2019A-LP-12-34']
# -- calibrations: []
#
# Visit 609
#  -- observations:
#  ['683-GS-2019A-LP-12-38']
# -- calibrations: []
#
# Visit 610
#  -- observations:
#  ['684-GS-2019A-LP-12-40']
# -- calibrations: []
#
# Visit 611
#  -- observations:
#  ['685-GS-2019A-LP-12-42']
# -- calibrations: []
#
# Visit 612
#  -- observations:
#  ['686-GS-2019A-LP-12-44']
# -- calibrations: []
#
# Visit 613
#  -- observations:
#  ['687-GS-2019A-LP-12-46']
# -- calibrations: []
#
# Visit 614
#  -- observations:
#  ['688-GS-2019A-LP-12-48']
# -- calibrations: []
#
# Visit 615
#  -- observations:
#  ['689-GS-2019A-LP-12-58']
# -- calibrations: []
#
# Visit 616
#  -- observations:
#  ['690-GS-2019A-LP-12-62']
# -- calibrations: []
#
# Visit 617
#  -- observations:
#  ['691-GS-2019A-LP-12-56']
# -- calibrations: []
#
# Visit 618
#  -- observations:
#  ['692-GS-2019A-LP-12-54']
# -- calibrations: []
#
# Visit 619
#  -- observations:
#  ['693-GS-2019A-LP-12-52']
# -- calibrations: []
#
# Visit 629
#  -- observations:
#  ['706-GS-2019A-Q-101-11', '707-GS-2019A-Q-101-12']
# -- calibrations: []
#
# Visit 630
#  -- observations:
#  ['708-GS-2019A-Q-101-14']
# -- calibrations: ['709-GS-2019A-Q-101-15']
#
# Visit 631
#  -- observations:
#  ['710-GS-2019A-Q-101-17']
# -- calibrations: ['711-GS-2019A-Q-101-18']
#
# Visit 646
#  -- observations:
#  ['726-GS-2019A-Q-109-29']
# -- calibrations: []
#
# Visit 647
#  -- observations:
#  ['727-GS-2019A-Q-109-36']
# -- calibrations: []
#
# Visit 648
#  -- observations:
#  ['728-GS-2019A-Q-109-43']
# -- calibrations: []
#
# Visit 649
#  -- observations:
#  ['729-GS-2019A-Q-109-44']
# -- calibrations: []
#
# Visit 651
#  -- observations:
#  ['731-GS-2019A-Q-109-28']
# -- calibrations: []
#
# Visit 653
#  -- observations:
#  ['733-GS-2019A-Q-109-31']
# -- calibrations: []
#
# Visit 654
#  -- observations:
#  ['734-GS-2019A-Q-109-49']
# -- calibrations: []
#
# Visit 769
#  -- observations:
#  ['872-GS-2019A-Q-129-3', '873-GS-2019A-Q-129-4']
# -- calibrations: []
#
# Visit 795
#  -- observations:
#  ['910-GS-2019A-Q-212-48']
# -- calibrations: []
